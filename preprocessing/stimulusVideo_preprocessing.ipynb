# %% [markdown]
# ### The below code performs
#
# 1. Renaming of the stimulus videos based on `Outcome`, `Temporality`, and `Anticipation`
# 2. Removes audio from the stimulus videos
# 3. Adds a black screen (lag) towards the end of the stimulus video (optional - in the final study, this step was not performed)
# 4. Calculate the video durations

# %%
import os
import numpy as np
import pandas as pd

from tqdm import tqdm
from moviepy.editor import VideoFileClip
from moviepy.editor import *

# %% [markdown]
# Installing MoviePy - check out the documentation at - [LINK](https://zulko.github.io/moviepy/install.html)
#
# The Library 'MoviePy' may not work having installed through pip. If that is the case, try installing it using 'Home Brew' for mac.

# %%
files_to_ignore = ['.DS_Store']
stimulus_data_info_path = '../../stimulus_dataset/stimulus_dataset_information.xlsx'
df = pd.read_excel(stimulus_data_info_path)
df
# Out:
#    Stimulus Video Name Outcome Temporality Anticipation  \
# 0              ch5.mp4    good      sudden   unexpected
# 1              cr4.mp4    good     gradual     expected
# 2              fh1.mp4     bad      sudden     expected
# 3              fh2.mp4     bad      sudden     expected
# 4              fh4.mp4     bad      sudden   unexpected
# ..                 ...     ...         ...          ...
# 81                 NaN     NaN         NaN          NaN
# 82                 NaN     NaN         NaN          NaN
# 83                 NaN     NaN         NaN          NaN
# 84                 NaN     NaN         NaN          NaN
# 85                 NaN     NaN         NaN          NaN
#
#                                    Brief Description Human/Robot  \
# 0   Human avoids being drenched in water from a wave       human
# 1                      Robot turns on a light switch       robot
# 2    Human falls trying to imitate pixar intro scene       human
# 3                Human fails at performing box jumps       human
# 4                        Falling off of a trampoline       human
# ..                                               ...         ...
# 81                                               NaN         NaN
# 82                                               NaN         NaN
# 83                                               NaN         NaN
# 84                                               NaN         NaN
# 85                                               NaN         NaN
#
#                                                Source Shortlist  \
# 0                                    SuperBAD dataset         Y
# 1                                    SuperBAD dataset         Y
# 2                                    SuperBAD dataset         M
# 3                                    SuperBAD dataset         M
# 4                                    SuperBAD dataset         M
# ..                                                ...       ...
# 81                                                NaN       NaN
# 82                                                NaN       NaN
# 83           Outcome Counts : {'bad': 30, 'good': 19}       NaN
# 84  Temporality Counts : {'gradual': 32, 'sudden':...       NaN
# 85  Anticipation Counts: {'unexpected': 28, 'expec...       NaN
#
#    Final_Shortlist Expected Outcomes  \
# 0                N               NaN
# 1                Y              Bad?
# 2                N               NaN
# 3                N               NaN
# 4                N               NaN
# ..             ...               ...
# 81             NaN               NaN
# 82             NaN               NaN
# 83             NaN               NaN
# 84             NaN               NaN
# 85             NaN               NaN
#
#                                              Comments  \
# 0                                                 NaN
# 1   I think people will see robot doing something ...
# 2               not enough time to understand context
# 3                    might be too obvious it goes bad
# 4                                                 NaN
# ..                                                ...
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
#
#            Final Video Name  Duration (s) When to Pause? (s)
# 0   good_unexp_sudden_1.mp4          8.70                NaN
# 1    good_exp_gradual_2.mp4         14.12                NaN
# 2      bad_sudden_exp_3.mp4          7.15                NaN
# 3      bad_sudden_exp_4.mp4         20.72                NaN
# 4    bad_sudden_unexp_5.mp4          6.77                NaN
# ..                      ...           ...                ...
# 81                      NaN           NaN                NaN
# 82                      NaN           NaN                NaN
# 83                      NaN           NaN                NaN
# 84                      NaN           NaN                NaN
# 85                      NaN           NaN                NaN
#
# [86 rows x 14 columns]

# %%
for index, row in df[49:60].iterrows():
#     print(row)
    outcome = row['Outcome']
    temporality = row['Temporality']
    anticipation = row['Anticipation']
    
    if anticipation == 'unexpected':
        anticipation = 'unexp'
    else:
        anticipation = 'exp'
    
    newVideoName = f"{outcome}_{temporality}_{anticipation}_{row['Stimulus Video Name']}"
    df.at[index, 'Final Video Name'] = newVideoName
    
    print(f"{row['Stimulus Video Name']}: {outcome}_{temporality}_{anticipation}")
df.to_csv('../stimulus_dataset/stimulus_dataset_information.csv', index=False)
# Out:
# 50.mp4: good_gradual_exp
# 51.mp4: good_gradual_exp
# 52.mp4: good_gradual_exp
# 53.mp4: good_gradual_exp
# 54.mp4: good_gradual_exp
# 55.mp4: good_gradual_exp
# 56.mp4: good_gradual_exp
# 57.mp4: good_gradual_exp
# ch2.mp4: good_gradual_exp
# ch3.mp4: good_gradual_exp
# ch4.mp4: good_gradual_exp

# %% [markdown]
# #### Rename videos

# %%
video_path = '../../stimulus_dataset/temp/'
videos = [video for video in os.listdir(video_path) if video not in files_to_ignore]
df = pd.read_csv('../../stimulus_dataset/stimulus_dataset_information.csv')

# %%
for video in sorted(videos):
    # Split the video file name by the dot to get the part before the extension
    filename_without_extension = video.split('.')[0]
    print(filename_without_extension)
    
    # Check if the part before the dot is an integer
    if filename_without_extension:
        for index, row in df[49:60].iterrows():
            newName = row['Final Video Name']
            if filename_without_extension == newName.split('.')[0].split('_')[-1]:
#                 print(filename_without_extension, newName)
                os.rename(f'../../stimulus_dataset/temp/{video}', f'../../stimulus_dataset/temp/{newName}')
# Out:
# 50
# 51
# 52
# 53
# 54
# 55
# 56
# 57
# ch2
# ch3
# ch4

# %% [markdown]
# #### Calculate stats

# %%
outcome_dict = df['Outcome'].value_counts().to_dict()
temporality_dict = df['Temporality'].value_counts().to_dict()
anticipation_dict = df['Anticipation'].value_counts().to_dict()
print(f'Outcome Counts : {outcome_dict}')
print(f'Temporality Counts : {temporality_dict}')
print(f'Anticipation Counts: {anticipation_dict}')
# Out:
# Outcome Counts : {'good': 30, 'bad': 30}
# Temporality Counts : {'gradual': 43, 'sudden': 17}
# Anticipation Counts: {'expected': 32, 'unexpected': 28}

# %% [markdown]
# ## Audio Removal Processing

# %% [markdown]
# Change the path of the 'directory' appropriately to choose the videos based on the class of the videos to be edited

# %%
directory = '../../stimulus_dataset/temp/'
newDirectory = '../../stimulus_dataset/new_temp/'


if not os.path.exists(newDirectory):
    os.mkdir(newDirectory)

# %%
# The videos for which the audio has to be removed
videos = sorted([video for video in os.listdir(directory) if video not in files_to_ignore])
videos
# Out:
# ['good_gradual_exp_50.mp4',
#  'good_gradual_exp_51.mp4',
#  'good_gradual_exp_52.mp4',
#  'good_gradual_exp_53.mp4',
#  'good_gradual_exp_54.mp4',
#  'good_gradual_exp_55.mp4',
#  'good_gradual_exp_56.mp4',
#  'good_gradual_exp_57.mp4',
#  'good_gradual_exp_ch2.mp4',
#  'good_gradual_exp_ch3.mp4',
#  'good_gradual_exp_ch4.mp4']

# %%
for video in videos:
#     print (element)
    videoClip = VideoFileClip(f"{directory}/{video}")
    noAudioClip = videoClip.without_audio()
    noAudioClip.write_videofile(f"{newDirectory}/{video}")
# Out:
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_50.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_50.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_50.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_51.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_51.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_51.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_52.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_52.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_52.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_53.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_53.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_53.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_54.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_54.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_54.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_55.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_55.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_55.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_56.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_56.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_56.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_57.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_57.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_57.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_ch2.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_ch2.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_ch2.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_ch3.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_ch3.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_ch3.mp4
# Moviepy - Building video ../stimulus_dataset/new_temp//good_gradual_exp_ch4.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//good_gradual_exp_ch4.mp4
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//good_gradual_exp_ch4.mp4

# %% [markdown]
# ## Lag addition - Black Screen

# %%
videos = sorted(os.listdir(newDirectory))
videos
# print(len(videos))
# print('\n'.join(sorted(videos)))
# Out:
# ['good_gradual_exp_46.mp4',
#  'good_gradual_exp_47.mp4',
#  'good_gradual_exp_48.mp4',
#  'good_gradual_exp_49.mp4']

# %% [markdown]
# If a .mp4 video file format is read and it is then converted or made any modifications to - to add the black screen, upon writing the file to local disk, the video files are corrupted - where the frames are frozen.
#
# To fix this, try converting your input video to a different format or codec before processing it with moviepy. You can use a tool like FFmpeg to convert the video. For example, you can try converting the video to H.264 format using the following command: ffmpeg -i input.mp4 -c:v libx264 -preset slow -crf 22 -c:a copy output.mp4.
#
# On mac - you can convert it into H.264 by right-clicking on the video file and selecting 'Encode Selected Video File' - and choosing the H.264 format.
#
# or run the code below and store the new encoded videos in a new directory and then perform the addition of lags

# %%
withLagDirectory = newDirectory + 'withLag'
if not os.path.exists(withLagDirectory):
    os.mkdir(withLagDirectory)

for vid in tqdm(videos, desc = 'Videos Processed: '):

# #   Optional - depends on what files you have in the directory - check once in the previous cell's code
#     if element == '.DS_Store' or element == 'withLag':
#         continue

    video = VideoFileClip(f'{newDirectory}/{vid}')

    # Create a black screen clip with duration
    black_screen = ColorClip((video.w, video.h), color=(0, 0, 0), duration=1)

    # # Concatenate the black screen clip with the original video
    # final_clip = concatenate_videoclips([black_screen, video])

    # Append the black screen clip to the end of the video
    final_clip = CompositeVideoClip([video, black_screen.set_start(video.duration)])
    
    video_name_parts = vid.split(".")
    video_name = video_name_parts[0]
    print('\n', video_name)

#     break
    final_clip.write_videofile(f'{newDirectory}/withLag/{video_name}.mp4')
# Out:
# Videos Processed:   0%|                                   | 0/4 [00:00<?, ?it/s]
#  good_gradual_exp_46
# Moviepy - Building video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_46.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_46.mp4
# t:   0%|                                      | 0/753 [00:00<?, ?it/s, now=None]
# t:   2%|▋                           | 18/753 [00:00<00:04, 178.06it/s, now=None]
# t:   5%|█▍                          | 37/753 [00:00<00:03, 181.74it/s, now=None]
# t:   7%|██                          | 56/753 [00:00<00:04, 140.81it/s, now=None]
# t:   9%|██▋                         | 71/753 [00:00<00:05, 129.84it/s, now=None]
# t:  11%|███▏                        | 85/753 [00:00<00:05, 127.01it/s, now=None]
# t:  13%|███▋                        | 99/753 [00:00<00:05, 125.15it/s, now=None]
# t:  15%|████                       | 112/753 [00:00<00:05, 120.99it/s, now=None]
# t:  17%|████▍                      | 125/753 [00:00<00:05, 116.01it/s, now=None]
# t:  18%|████▉                      | 138/753 [00:01<00:05, 116.18it/s, now=None]
# t:  20%|█████▍                     | 150/753 [00:01<00:05, 113.65it/s, now=None]
# t:  22%|█████▊                     | 162/753 [00:01<00:05, 111.99it/s, now=None]
# t:  23%|██████▏                    | 174/753 [00:01<00:05, 111.24it/s, now=None]
# t:  25%|██████▋                    | 186/753 [00:01<00:05, 109.36it/s, now=None]
# t:  26%|███████                    | 197/753 [00:01<00:05, 108.94it/s, now=None]
# t:  28%|███████▍                   | 208/753 [00:01<00:05, 108.81it/s, now=None]
# t:  29%|███████▊                   | 219/753 [00:01<00:04, 107.34it/s, now=None]
# t:  31%|████████▏                  | 230/753 [00:01<00:04, 106.11it/s, now=None]
# t:  32%|████████▋                  | 241/753 [00:02<00:04, 103.15it/s, now=None]
# t:  33%|█████████                  | 252/753 [00:02<00:04, 103.26it/s, now=None]
# t:  35%|█████████▍                 | 263/753 [00:02<00:04, 104.26it/s, now=None]
# t:  36%|█████████▊                 | 274/753 [00:02<00:04, 104.93it/s, now=None]
# t:  38%|██████████▎                | 286/753 [00:02<00:04, 107.35it/s, now=None]
# t:  40%|██████████▋                | 298/753 [00:02<00:04, 109.38it/s, now=None]
# t:  41%|███████████                | 310/753 [00:02<00:03, 111.45it/s, now=None]
# t:  43%|███████████▌               | 322/753 [00:02<00:03, 112.83it/s, now=None]
# t:  44%|███████████▉               | 334/753 [00:02<00:03, 112.32it/s, now=None]
# t:  46%|████████████▍              | 347/753 [00:03<00:03, 115.46it/s, now=None]
# t:  48%|████████████▉              | 360/753 [00:03<00:03, 117.40it/s, now=None]
# t:  50%|█████████████▎             | 373/753 [00:03<00:03, 120.18it/s, now=None]
# t:  51%|█████████████▊             | 386/753 [00:03<00:03, 122.04it/s, now=None]
# t:  53%|██████████████▎            | 399/753 [00:03<00:02, 120.29it/s, now=None]
# t:  55%|██████████████▊            | 412/753 [00:03<00:02, 116.57it/s, now=None]
# t:  56%|███████████████▏           | 424/753 [00:03<00:02, 110.93it/s, now=None]
# t:  58%|███████████████▋           | 436/753 [00:03<00:02, 109.71it/s, now=None]
# t:  59%|████████████████           | 448/753 [00:03<00:02, 109.34it/s, now=None]
# t:  61%|████████████████▍          | 460/753 [00:04<00:02, 110.27it/s, now=None]
# t:  63%|████████████████▉          | 472/753 [00:04<00:02, 110.97it/s, now=None]
# t:  64%|█████████████████▎         | 484/753 [00:04<00:02, 108.25it/s, now=None]
# t:  66%|█████████████████▊         | 496/753 [00:04<00:02, 109.12it/s, now=None]
# t:  67%|██████████████████▏        | 507/753 [00:04<00:02, 108.33it/s, now=None]
# t:  69%|██████████████████▌        | 518/753 [00:04<00:02, 107.41it/s, now=None]
# t:  70%|██████████████████▉        | 529/753 [00:04<00:02, 107.64it/s, now=None]
# t:  72%|███████████████████▎       | 540/753 [00:04<00:01, 106.55it/s, now=None]
# t:  73%|███████████████████▊       | 551/753 [00:04<00:01, 104.20it/s, now=None]
# t:  75%|████████████████████▏      | 563/753 [00:04<00:01, 106.76it/s, now=None]
# t:  76%|████████████████████▌      | 574/753 [00:05<00:01, 106.03it/s, now=None]
# t:  78%|█████████████████████      | 586/753 [00:05<00:01, 107.65it/s, now=None]
# t:  79%|█████████████████████▍     | 597/753 [00:05<00:01, 105.04it/s, now=None]
# t:  81%|█████████████████████▊     | 608/753 [00:05<00:01, 105.91it/s, now=None]
# t:  82%|██████████████████████▏    | 619/753 [00:05<00:01, 105.71it/s, now=None]
# t:  84%|██████████████████████▌    | 630/753 [00:05<00:01, 104.39it/s, now=None]
# t:  85%|██████████████████████▉    | 641/753 [00:05<00:01, 103.72it/s, now=None]
# t:  87%|███████████████████████▍   | 652/753 [00:05<00:00, 104.67it/s, now=None]
# t:  88%|███████████████████████▊   | 663/753 [00:05<00:00, 103.99it/s, now=None]
# t:  90%|████████████████████████▏  | 674/753 [00:06<00:00, 103.17it/s, now=None]
# t:  91%|████████████████████████▌  | 685/753 [00:06<00:00, 104.31it/s, now=None]
# t:  92%|████████████████████████▉  | 696/753 [00:06<00:00, 103.88it/s, now=None]
# t:  94%|█████████████████████████▍ | 708/753 [00:06<00:00, 106.44it/s, now=None]
# t:  95%|█████████████████████████▊ | 719/753 [00:06<00:00, 106.74it/s, now=None]
# t:  97%|██████████████████████████▏| 731/753 [00:06<00:00, 110.48it/s, now=None]
# t:  99%|██████████████████████████▋| 744/753 [00:06<00:00, 114.53it/s, now=None]
# Videos Processed:  25%|██████▊                    | 1/4 [00:07<00:20,  6.97s/it]
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//withLag/good_gradual_exp_46.mp4
#
#  good_gradual_exp_47
# Moviepy - Building video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_47.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_47.mp4
# t:   0%|                                      | 0/948 [00:00<?, ?it/s, now=None]
# t:   4%|█▏                          | 39/948 [00:00<00:02, 387.00it/s, now=None]
# t:   8%|██▎                         | 78/948 [00:00<00:03, 277.71it/s, now=None]
# t:  11%|███                        | 108/948 [00:00<00:03, 265.18it/s, now=None]
# t:  14%|███▊                       | 136/948 [00:00<00:03, 256.68it/s, now=None]
# t:  17%|████▋                      | 163/948 [00:00<00:03, 254.34it/s, now=None]
# t:  20%|█████▍                     | 189/948 [00:00<00:03, 248.89it/s, now=None]
# t:  23%|██████                     | 215/948 [00:00<00:03, 241.98it/s, now=None]
# t:  25%|██████▊                    | 240/948 [00:00<00:02, 241.33it/s, now=None]
# t:  28%|███████▌                   | 265/948 [00:01<00:02, 239.84it/s, now=None]
# t:  31%|████████▎                  | 290/948 [00:01<00:02, 237.17it/s, now=None]
# t:  33%|████████▉                  | 314/948 [00:01<00:02, 228.41it/s, now=None]
# t:  36%|█████████▋                 | 338/948 [00:01<00:02, 230.10it/s, now=None]
# t:  38%|██████████▎                | 362/948 [00:01<00:02, 209.19it/s, now=None]
# t:  41%|██████████▉                | 385/948 [00:01<00:02, 211.12it/s, now=None]
# t:  43%|███████████▋               | 410/948 [00:01<00:02, 220.50it/s, now=None]
# t:  46%|████████████▍              | 435/948 [00:01<00:02, 226.94it/s, now=None]
# t:  49%|█████████████▏             | 461/948 [00:01<00:02, 234.48it/s, now=None]
# t:  51%|█████████████▊             | 486/948 [00:02<00:01, 236.85it/s, now=None]
# t:  54%|██████████████▌            | 510/948 [00:02<00:01, 235.81it/s, now=None]
# t:  56%|███████████████▏           | 534/948 [00:02<00:01, 235.09it/s, now=None]
# t:  59%|███████████████▉           | 558/948 [00:02<00:01, 233.87it/s, now=None]
# t:  61%|████████████████▌          | 582/948 [00:02<00:01, 232.84it/s, now=None]
# t:  64%|█████████████████▎         | 606/948 [00:02<00:01, 227.48it/s, now=None]
# t:  66%|█████████████████▉         | 629/948 [00:02<00:01, 226.31it/s, now=None]
# t:  69%|██████████████████▌        | 653/948 [00:02<00:01, 228.54it/s, now=None]
# t:  71%|███████████████████▎       | 676/948 [00:02<00:01, 222.03it/s, now=None]
# t:  74%|███████████████████▉       | 699/948 [00:02<00:01, 214.80it/s, now=None]
# t:  76%|████████████████████▌      | 721/948 [00:03<00:01, 211.70it/s, now=None]
# t:  78%|█████████████████████▏     | 743/948 [00:03<00:00, 210.43it/s, now=None]
# t:  81%|█████████████████████▊     | 767/948 [00:03<00:00, 216.55it/s, now=None]
# t:  83%|██████████████████████▌    | 790/948 [00:03<00:00, 216.35it/s, now=None]
# t:  86%|███████████████████████▏   | 813/948 [00:03<00:00, 217.92it/s, now=None]
# t:  88%|███████████████████████▊   | 835/948 [00:03<00:00, 211.78it/s, now=None]
# t:  90%|████████████████████████▍  | 857/948 [00:03<00:00, 212.84it/s, now=None]
# t:  93%|█████████████████████████  | 879/948 [00:03<00:00, 214.46it/s, now=None]
# t:  95%|█████████████████████████▋ | 901/948 [00:03<00:00, 214.42it/s, now=None]
# t:  97%|██████████████████████████▎| 924/948 [00:04<00:00, 216.25it/s, now=None]
# t: 100%|███████████████████████████| 948/948 [00:04<00:00, 220.80it/s, now=None]
# Videos Processed:  50%|█████████████▌             | 2/4 [00:11<00:10,  5.39s/it]
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//withLag/good_gradual_exp_47.mp4
#
#  good_gradual_exp_48
# Moviepy - Building video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_48.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_48.mp4
# t:   0%|                                      | 0/497 [00:00<?, ?it/s, now=None]
# t:  10%|██▊                         | 51/497 [00:00<00:00, 504.21it/s, now=None]
# t:  21%|█████▌                     | 102/497 [00:00<00:00, 455.22it/s, now=None]
# t:  30%|████████                   | 148/497 [00:00<00:00, 453.01it/s, now=None]
# t:  39%|██████████▌                | 194/497 [00:00<00:00, 424.83it/s, now=None]
# t:  48%|████████████▉              | 237/497 [00:00<00:00, 420.79it/s, now=None]
# t:  56%|███████████████▏           | 280/497 [00:00<00:00, 423.42it/s, now=None]
# t:  65%|█████████████████▌         | 323/497 [00:00<00:00, 420.94it/s, now=None]
# t:  75%|████████████████████▏      | 371/497 [00:00<00:00, 437.81it/s, now=None]
# t:  84%|██████████████████████▌    | 415/497 [00:00<00:00, 434.90it/s, now=None]
# t:  93%|█████████████████████████▏ | 464/497 [00:01<00:00, 449.19it/s, now=None]
# Videos Processed:  75%|████████████████████▎      | 3/4 [00:12<00:03,  3.47s/it]
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//withLag/good_gradual_exp_48.mp4
#
#  good_gradual_exp_49
# Moviepy - Building video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_49.mp4.
# Moviepy - Writing video ../stimulus_dataset/new_temp//withLag/good_gradual_exp_49.mp4
# t:   0%|                                      | 0/821 [00:00<?, ?it/s, now=None]
# t:   7%|██                          | 61/821 [00:00<00:01, 602.20it/s, now=None]
# t:  15%|████                       | 122/821 [00:00<00:01, 570.80it/s, now=None]
# t:  22%|█████▉                     | 180/821 [00:00<00:01, 543.12it/s, now=None]
# t:  29%|███████▊                   | 236/821 [00:00<00:01, 547.17it/s, now=None]
# t:  35%|█████████▌                 | 291/821 [00:00<00:00, 544.73it/s, now=None]
# t:  42%|███████████▍               | 346/821 [00:00<00:00, 538.52it/s, now=None]
# t:  49%|█████████████▏             | 400/821 [00:00<00:00, 536.62it/s, now=None]
# t:  55%|██████████████▉            | 454/821 [00:00<00:00, 534.58it/s, now=None]
# t:  62%|████████████████▋          | 508/821 [00:00<00:00, 528.82it/s, now=None]
# t:  68%|██████████████████▍        | 561/821 [00:01<00:00, 521.06it/s, now=None]
# t:  75%|████████████████████▏      | 614/821 [00:01<00:00, 518.41it/s, now=None]
# t:  81%|█████████████████████▉     | 666/821 [00:01<00:00, 510.97it/s, now=None]
# t:  88%|███████████████████████▋   | 720/821 [00:01<00:00, 518.47it/s, now=None]
# t:  95%|█████████████████████████▌ | 776/821 [00:01<00:00, 528.97it/s, now=None]
# Videos Processed: 100%|███████████████████████████| 4/4 [00:14<00:00,  3.51s/it]
# Moviepy - Done !
# Moviepy - video ready ../stimulus_dataset/new_temp//withLag/good_gradual_exp_49.mp4

# %% [markdown]
# #### Calculate video durations

# %% [markdown]
# First move the new stimulus videos from `new_temp/withLag` to the stimulusVideos directory and then run the below code or change the directory appropriately to calculate the video durations + make sure the `Final Video Name` of the stimulusVideo is updated in teh `stimulus_dataset_information.xlsx`

# %%
df = pd.read_excel('../../stimulus_dataset/stimulus_dataset_information.xlsx')
stimulus_video_path = '../../stimulus_dataset/stimulusVideos/'
videos = sorted([video for video in os.listdir(stimulus_video_path) if video not in files_to_ignore])
# print(videos)
for vid in sorted(videos):
    # Load the video file
    video_path = f"../../stimulus_dataset/stimulusVideos/{vid}"
    video = VideoFileClip(video_path)

    # Get the duration of the video in seconds
    duration = video.duration
    for index, row in df.iterrows():
        if vid == row['Final Video Name']:
            df.at[index, 'Duration'] = duration

#     # Print the duration in seconds
#     print(f"Video = {vid} & duration: {duration} seconds")

#     # Optionally, you can also convert the duration to minutes and seconds
#     minutes, seconds = divmod(duration, 60)
#     print(f"Video duration: {minutes} minutes and {seconds} seconds")
df
# Out:
#    Stimulus Video Name Outcome Temporality Anticipation  \
# 0              ch5.mp4    good      sudden   unexpected
# 1              cr4.mp4    good     gradual     expected
# 2              fh1.mp4     bad      sudden     expected
# 3              fh2.mp4     bad      sudden     expected
# 4              fh4.mp4     bad      sudden   unexpected
# 5              fh5.mp4     bad      sudden   unexpected
# 6              fh7.mp4     bad      sudden     expected
# 7              fh9.mp4     bad     gradual     expected
# 8              fr1.mp4     bad     gradual     expected
# 9              fr2.mp4     bad      sudden   unexpected
# 10             fr6.mp4     bad     gradual   unexpected
# 11             fr7.mp4     bad      sudden   unexpected
# 12             fr8.mp4     bad     gradual     expected
# 13             fr9.mp4     bad     gradual     expected
# 14            fr10.mp4     bad      sudden   unexpected
# 15              16.mp4     bad      sudden   unexpected
# 16              17.mp4     bad      sudden   unexpected
# 17              18.mp4    good     gradual   unexpected
# 18              19.mp4    good     gradual   unexpected
# 19              20.mp4     bad     gradual     expected
# 20              21.mp4    good     gradual     expected
# 21              22.mp4     bad      sudden     expected
# 22              23.mp4     bad     gradual   unexpected
# 23              24.mp4    good     gradual   unexpected
# 24              25.mp4     bad     gradual   unexpected
# 25              26.mp4    good     gradual   unexpected
# 26              27.mp4     bad      sudden   unexpected
# 27              28.mp4    good     gradual   unexpected
# 28              29.mp4     bad      sudden   unexpected
# 29              30.mp4     bad     gradual   unexpected
# 30              31.mp4     bad     gradual     expected
# 31              32.mp4     bad     gradual     expected
# 32              33.mp4    good     gradual   unexpected
# 33              34.mp4     bad     gradual     expected
# 34              35.mp4     bad     gradual     expected
# 35              36.mp4     bad      sudden   unexpected
# 36              37.mp4    good     gradual   unexpected
# 37              38.mp4     bad      sudden     expected
# 38              39.mp4     bad     gradual   unexpected
# 39              40.mp4     bad      sudden   unexpected
# 40              41.mp4    good     gradual   unexpected
# 41              42.mp4    good     gradual   unexpected
# 42              43.mp4    good     gradual   unexpected
# 43              44.mp4    good     gradual     expected
# 44              45.mp4    good     gradual   unexpected
# 45              46.mp4    good     gradual     expected
# 46              47.mp4    good     gradual     expected
# 47             cr3.mp4    good     gradual     expected
# 48             cr5.mp4    good     gradual     expected
# 49                 NaN     NaN         NaN          NaN
# 50                 NaN     NaN         NaN          NaN
# 51                 NaN     NaN         NaN          NaN
# 52                 NaN     NaN         NaN          NaN
# 53                 NaN     NaN         NaN          NaN
# 54                 NaN     NaN         NaN          NaN
# 55                 NaN     NaN         NaN          NaN
# 56                 NaN     NaN         NaN          NaN
# 57                 NaN     NaN         NaN          NaN
# 58                 NaN     NaN         NaN          NaN
#
#                                     Brief Description Human/Robot  \
# 0    Human avoids being drenched in water from a wave       human
# 1                       Robot turns on a light switch       robot
# 2     Human falls trying to imitate pixar intro scene       human
# 3                 Human fails at performing box jumps       human
# 4                         Falling off of a trampoline       human
# 5    Human crashes into another person on a lawnmover       human
# 6   Human crashes into a christman tree on a hover...       human
# 7   Human fails at stocking wines and causes wine ...       human
# 8                Humanoid Robot moving back and forth       robot
# 9         Robotic arm feeding cheeots to a mannequin        robot
# 10       Humanoid robot losing balance while standing       robot
# 11    Robotic arm punching a baby trying to feed milk       robot
# 12          Humanoid robot failing at climbing stairs       robot
# 13  Robot fails at handing over a coke can success...       robot
# 14                  Robot fails to jump across planks       robot
# 15  A woman fails at diving into the ocean from a ...       human
# 16  A person dressed in a spiderman costume fails ...       human
# 17  A man successfully catches a baby lookalike to...       human
# 18  A man successfully rides a bicycle while stand...       human
# 19        A man falls sitting ontop a stack of tables       human
# 20  A man successfully performs a stunt on his bic...       human
# 21  A man falls while jumping on a trampoline with...       human
# 22  A man falls while trying to jump off of cliff ...       human
# 23  A group of friends successfully swing ontop of...       human
# 24  A man fails at swinging from a jumpline from a...       human
# 25  A man successfully crossed a bridge made out o...       human
# 26  A man is almost crashed by a car while sleepin...       human
# 27  A man crosses a lake filled with crocodiles on...       human
# 28  A man fails at performing a stunt near a pond ...       human
# 29  A man fails at performing a stunt on his skate...       human
# 30                        A kid drops a cup of coffee       human
# 31               A kid kicks a football into a window       human
# 32  A man successfully parks a car next to a swimm...       human
# 33  A man fails to jump onto a moving truck from a...       human
# 34                  A man fails to jump off of a boat       human
# 35  A man gets shocked by a wave of electricity wh...       human
# 36  A group of people successfully pull of a stunt...       human
# 37  A man gets caught by officials while trying to...       human
# 38  A man drops his gifts while trying to enter a ...       human
# 39  A woman falls inside a road while tyring to ex...       human
# 40                A person jumping between train cars       human
# 41                              A parrot scares a dog       other
# 42    A mysterious man hands a kitten from his hoodie       human
# 43                   A person jumps between buildings       human
# 44               A fish escapes being eaten by a duck       other
# 45  A robot moves a container from a shelf to a co...       robot
# 46  A robot moves a container from a shelf to a table       robot
# 47  A robot picks up clothes fallen down on the floor       robot
# 48  A robot places a glass in the dishwasher and a...       robot
# 49                                                NaN         NaN
# 50                                                NaN         NaN
# 51                                                            NaN
# 52                                                NaN         NaN
# 53                                                NaN         NaN
# 54                                                NaN         NaN
# 55                                                NaN         NaN
# 56                                                NaN         NaN
# 57                                                NaN         NaN
# 58                                                NaN         NaN
#
#                                                Source Shortlist  \
# 0                                    SuperBAD dataset         Y
# 1                                    SuperBAD dataset         Y
# 2                                    SuperBAD dataset         M
# 3                                    SuperBAD dataset         M
# 4                                    SuperBAD dataset         M
# 5                                    SuperBAD dataset         Y
# 6                                    SuperBAD dataset       Y_p
# 7                                    SuperBAD dataset         N
# 8                                    SuperBAD dataset       Y_p
# 9                                    SuperBAD dataset         M
# 10                                   SuperBAD dataset         Y
# 11                                   SuperBAD dataset       Y_p
# 12                                   SuperBAD dataset         Y
# 13                                   SuperBAD dataset         M
# 14                                   SuperBAD dataset       Y_p
# 15                                             Reddit         M
# 16                                             Reddit         M
# 17                                             Reddit         N
# 18                                             Reddit         Y
# 19                                             Reddit         Y
# 20                                             Reddit         Y
# 21                                             Reddit         Y
# 22                                             Reddit         M
# 23                                             Reddit         Y
# 24                                             Reddit         Y
# 25                                             Reddit         Y
# 26                                             Reddit         N
# 27                                             Reddit         M
# 28                                             Reddit         Y
# 29                                             Reddit       Y_p
# 30                                             Reddit         M
# 31                                             Reddit         Y
# 32                                             Reddit       Y_p
# 33                                             Reddit         Y
# 34                                             Reddit         N
# 35                                             Reddit         Y
# 36                                             Reddit         M
# 37                                             Reddit         M
# 38                                             Reddit         Y
# 39                                             Reddit         M
# 40                                             Reddit       Y_p
# 41                                             Reddit         N
# 42                                             Reddit         N
# 43                                             Reddit       Y_p
# 44                                             Reddit         N
# 45                                             Reddit       Y_p
# 46                                             Reddit       Y_p
# 47                                   SuperBAD dataset       NaN
# 48                                   SuperBAD dataset       NaN
# 49                                                NaN       NaN
# 50                                                NaN       NaN
# 51                                                NaN       NaN
# 52                                          Yes Count        17
# 53                                             Maybe         13
# 54                                                 No         4
# 55                                                NaN       NaN
# 56           Outcome Counts : {'bad': 30, 'good': 15}       NaN
# 57  Temporality Counts : {'gradual': 28, 'sudden':...       NaN
# 58  Anticipation Counts: {'unexpected': 28, 'expec...       NaN
#
#                                              Comments  \
# 0                                                 NaN
# 1                                                 NaN
# 2               not enough time to understand context
# 3                    might be too obvious it goes bad
# 4   we already have other trampoline videos. Maybe...
# 5                                                 NaN
# 6                                                 NaN
# 7         not enough resolution, happens too suddenly
# 8       might need to investigate where to stop video
# 9   I think people might not understand intention ...
# 10                                                NaN
# 11                                    still got audio
# 12         not sure if has enough time before outcome
# 13        unsure about how people will interpret this
# 14                                                NaN
# 15             edited already, but could be an option
# 16              this would be great without a failure
# 17  hilarious ahaha but the "dd reflexes" already ...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22              not sure how to classify this outcome
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  this situation is an accident so there's not r...
# 27  maybe participant's won't understand the context?
# 28                                                NaN
# 29                                     needs cropping
# 30                                     needs cropping
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34          too obvious as person is already slipping
# 35                                     needs cropping
# 36                      not super clear what happened
# 37  hilarious, but might be too complex to be aski...
# 38                                                NaN
# 39                                     needs cropping
# 40                                                NaN
# 41  not clear enough what to answer to"is this a b...
# 42              hilarious ahah but not enough context
# 43                                                NaN
# 44  there is no sense of agency  here. "good idea"...
# 45                                      MISSING VIDEO
# 46                                      MISSING VIDEO
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                            Final Video Name  Duration (s)  \
# 0                   good_unexp_sudden_1.mp4          8.70
# 1                    good_exp_gradual_2.mp4         14.12
# 2                      bad_sudden_exp_3.mp4          7.15
# 3                      bad_sudden_exp_4.mp4         20.72
# 4                    bad_sudden_unexp_5.mp4          6.77
# 5                    bad_sudden_enexp_6.mp4          7.64
# 6                      bad_sudden_exp_7.mp4          9.84
# 7                     bad_gradual_exp_8.mp4         13.08
# 8                     bad_gradual_exp_9.mp4         11.43
# 9                   bad_sudden_unexp_10.mp4         11.30
# 10                 bad_gradual_unexp_11.mp4         21.33
# 11                  bad_sudden_unexp_12.mp4          8.53
# 12                   bad_gradual_exp_13.mp4          6.93
# 13                   bad_gradual_exp_14.mp4         14.88
# 14                  bad_sudden_unexp_15.mp4          7.48
# 15                  bad_sudden_unexp_16.mp4         20.30
# 16                  bad_sudden_unexp_17.mp4          7.80
# 17                good_gradual_unexp_18.mp4          9.60
# 18                good_gradual_unexp_19.mp4         41.50
# 19                   bad_gradual_exp_20.mp4         25.70
# 20                  good_gradual_exp_21.mp4         12.80
# 21                    bad_sudden_exp_22.mp4          8.10
# 22                 bad_gradual_unexp_23.mp4         15.10
# 23                good_gradual_unexp_24.mp4         57.83
# 24                 bad_gradual_unexp_25.mp4          7.00
# 25                good_gradual_unexp_26.mp4         34.43
# 26                  bad_sudden_unexp_27.mp4         11.40
# 27                good_gradual_unexp_28.mp4         40.30
# 28                  bad_sudden_unexp_29.mp4          8.20
# 29                 bad_gradual_unexp_30.mp4         44.03
# 30                   bad_gradual_exp_31.mp4         18.73
# 31                   bad_gradual_exp_32.mp4         11.80
# 32                good_gradual_unexp_33.mp4         32.73
# 33                   bad_gradual_exp_34.mp4          9.33
# 34                   bad_gradual_exp_35.mp4         15.90
# 35                  bad_sudden_unexp_36.mp4         23.20
# 36                good_gradual_unexp_37.mp4         12.50
# 37                    bad_sudden_exp_38.mp4         12.60
# 38                 bad_gradual_unexp_39.mp4         27.70
# 39                  bad_sudden_unexp_40.mp4         11.50
# 40                good_gradual_unexp_41.mp4         15.83
# 41                good_gradual_unexp_42.mp4         17.20
# 42                good_gradual_unexp_43.mp4         13.60
# 43                  good_gradual_exp_44.mp4         22.00
# 44                good_gradual_unexp_45.mp4         61.90
# 45                  good_gradual_exp_46.mp4           NaN
# 46                  good_gradual_exp_47.mp4           NaN
# 47                  good_gradual_exp_48.mp4           NaN
# 48                  good_gradual_exp_49.mp4           NaN
# 49  Total Duration of dataset videos (s) =         820.51
# 50                                      NaN           NaN
# 51                                      NaN           NaN
# 52                                      NaN           NaN
# 53                                      NaN           NaN
# 54                                      NaN           NaN
# 55                                      NaN           NaN
# 56                                      NaN           NaN
# 57                                      NaN           NaN
# 58                                      NaN           NaN
#
#                      When to Pause? (s)  Duration
# 0                                   NaN      8.70
# 1                                   NaN     14.12
# 2                                   NaN      7.15
# 3                                   NaN     20.72
# 4                                   NaN      6.77
# 5                                   NaN      7.64
# 6                                    4s      9.84
# 7                                   NaN     13.08
# 8   7.5 s approx. and cut 1s from start     11.43
# 9                                   NaN     11.30
# 10                                  NaN     21.33
# 11   5s, before the arm extends at all!      8.53
# 12                                  NaN      6.93
# 13                                  NaN     14.88
# 14   4  s, right as it prepares to jump      7.48
# 15                                  NaN     20.30
# 16                                  NaN      7.80
# 17                                  NaN      9.60
# 18                                  NaN     41.50
# 19                                  NaN     25.70
# 20                                  NaN     12.80
# 21                                  NaN      8.10
# 22                                  NaN     15.10
# 23                                  NaN     57.83
# 24                                  NaN      7.00
# 25                                  NaN     34.43
# 26                                  NaN     11.40
# 27                                  NaN     40.30
# 28                                  NaN      8.20
# 29                              13-18 s     44.03
# 30                                  NaN     18.73
# 31                                  NaN     11.80
# 32                                    4     32.73
# 33                                  NaN      9.33
# 34                                  NaN     15.90
# 35                                  NaN     23.20
# 36                                  NaN     12.50
# 37                                  NaN     12.60
# 38                                  NaN     27.70
# 39                                  NaN     11.50
# 40                                    6     15.83
# 41                                  NaN     17.20
# 42                                  NaN     13.60
# 43                                    4     22.00
# 44                                  NaN     61.90
# 45                                  NaN     25.10
# 46                                  NaN     31.60
# 47                                  NaN     16.58
# 48                                  NaN     27.40
# 49                                  NaN       NaN
# 50                                  NaN       NaN
# 51                                  NaN       NaN
# 52                                  NaN       NaN
# 53                                  NaN       NaN
# 54                                  NaN       NaN
# 55                                  NaN       NaN
# 56                                  NaN       NaN
# 57                                  NaN       NaN
# 58                                  NaN       NaN

# %%
df.to_csv('../../stimulus_dataset/stimulus_dataset_information.csv', index = False)
